# %% [markdown]
# ## Training your own openWakeWord models

# %% [markdown]
# **Quick-start:** If you just want to train a basic custom model for openWakeWord!
#
# Follow the instructions for Step 1 below. Each time you change the wake word, click the play icon to the left of the title to generate a sample and make sure it sounds correct. The first time it takes a few minutes but subsequent runs will be quick.
#
# Once you're satisfied with the pronounciation, go to the "Runtime" dropdown menu in the upper left of the page, and select "run all". Keep the tab open but feel free to do something else. After ~1 hour, your custom model will be ready and will automatically be downloaded to your computer!
#
# If you are a Home Assistant user with the openWakeWord add-on, follow the instructions [here](https://github.com/home-assistant/addons/blob/master/openwakeword/DOCS.md#custom-wake-word-models) to install and enable your custom model.
#
# ---
#
# If you are interested in learning more about the custom model training process (and increasing the accuracy of your custom models), read through each step in this notebook and try experimenting with different training parameters. If you have any questions or problems, feel free to start a discussion at the openWakeWord [repo](https://github.com/dscripka/openWakeWord/discussions).

# %%
# @title  { display-mode: "form" }
# @markdown # 1. Test Example Training Clip Generation

import os
import sys
from IPython.display import Audio

if not os.path.exists("./piper-sample-generator"):
    # !git clone https://github.com/rhasspy/piper-sample-generator
    # !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt \
        'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
    # !cd piper-sample-generator && git checkout 213d4d5

    # !pip install piper-tts piper-phonemize-cross
    # !pip install webrtcvad
    # !pip install 'torch<=2.5' torchvision torchaudio

# These should ALWAYS run
if "piper-sample-generator/" not in sys.path:
    sys.path.append("piper-sample-generator/")

from generate_samples import generate_samples

target_word = 'dayn_jer di_tected'  # @param {type:"string"}

def text_to_speech(text):
    generate_samples(
        text=text,
        max_samples=1,
        length_scales=[1.1],
        noise_scales=[0.7],
        noise_scale_ws=[0.7],
        output_dir='./',
        batch_size=1,
        auto_reduce_batch_size=True,
        file_names=["test_generation.wav"]
    )

text_to_speech(target_word)
Audio("test_generation.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# @title  { display-mode: "form" }
# @markdown # 2. Download Data
# @markdown Training custom models requires downloading a wide variety of data
# @markdown that will help make the model perform well in real-world scenarios.
# @markdown This example notebook will download small samples of background noise,
# @markdown music, and Room Impulse Responses (to add echo). This will still produce
# @markdown a custom model that performs well, but if you are interested in adding even more,
# @markdown feel free to extend this notebook to download the full datasets and even add
# @markdown your own!
# @markdown
# @markdown Downloading this example data will usually take about 15 minutes.

# @markdown **Important note!** The data downloaded here has a mixture of different
# @markdown licenses and usage restrictions. As such, any custom models trained with this
# @markdown data should be considered as appropriate for **non-commercial** personal use only.

# ## Install all dependencies
# !pip install datasets
# !pip install scipy
# !pip install tqdm

import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# install openwakeword (full installation to support training)
# !git clone https://github.com/dscripka/openwakeword
# !pip install -e ./openwakeword --no-deps
# !cd openwakeword

# install other dependencies
# !pip install mutagen==1.47.0
# !pip install torchinfo==1.8.0
# !pip install torchmetrics==1.2.0
# !pip install speechbrain==0.5.14
# !pip install audiomentations==0.33.0
# !pip install torch-audiomentations==0.11.0
# !pip install acoustics==0.2.6
# !pip uninstall tensorflow -y
# !pip install tensorflow-cpu==2.8.1
# !pip install protobuf==3.20.3
# !pip install tensorflow_probability==0.16.0
# !pip install onnx_tf==1.10.0
# !pip install onnxruntime==1.22.1 ai_edge_litert==1.4.0 onnxsim
# !pip install onnx2tf
# !pip install onnx==1.19.1
# !pip install ai_edge_litert==1.2.0
# !pip install onnx_graphsurgeon
# !pip install sng4onnx
# !pip install pronouncing==0.2.0
# !pip install datasets==2.14.6
# !pip install deep-phonemizer==0.0.19

# Download required models (workaround for Colab)
import os
os.makedirs("./openwakeword/openwakeword/resources/models", exist_ok=True)
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx -O ./openwakeword/openwakeword/resources/models/embedding_model.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite -O ./openwakeword/openwakeword/resources/models/embedding_model.tflite
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx -O ./openwakeword/openwakeword/resources/models/melspectrogram.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite -O ./openwakeword/openwakeword/resources/models/melspectrogram.tflite

# Imports
import sys

if "piper-sample-generator/" not in sys.path:
    sys.path.append("piper-sample-generator/")
from generate_samples import generate_samples

import numpy as np
import torch
import sys
from pathlib import Path
import uuid
import yaml
import datasets
import scipy
from tqdm import tqdm

## Download all data

## Download MIR RIR data (takes about ~2 minutes)
output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    # !git lfs install
    # !git clone https://huggingface.co/datasets/davidscripka/MIT_environmental_impulse_responses
    rir_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("./MIT_environmental_impulse_responses/16khz").glob("*.wav")]}).cast_column("audio", datasets.Audio())
    # Save clips to 16-bit PCM wav files
    for row in tqdm(rir_dataset):
        name = row['audio']['path'].split('/')[-1]
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

## Download noise and background audio (takes about ~3 minutes)

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

    fname = "bal_train09.tar"
    out_dir = f"audioset/{fname}"
    link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
    # !wget -O {out_dir} {link}
    # !cd audioset && tar -xvf bal_train09.tar

    output_dir = "./audioset_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Save clips to 16-bit PCM wav files
    audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
    audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
    for row in tqdm(audioset_dataset):
        name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset
# https://github.com/mdeff/fma

output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    fma_dataset = datasets.load_dataset("rudraml/fma", name="small", split="train", streaming=True)
    fma_dataset = iter(fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000)))

    # Save clips to 16-bit PCM wav files
    n_hours = 1  # use only 1 hour of clips for this example notebook, recommend increasing for full-scale training
    for i in tqdm(range(n_hours*3600//30)):  # this works because the FMA dataset is all 30 second clips
        row = next(fma_dataset)
        name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
        i += 1
        if i == n_hours*3600//30:
            break

# Download pre-computed openWakeWord features for training and validation

# training set (~2,000 hours from the ACAV100M Dataset)
# See https://huggingface.co/datasets/davidscripka/openwakeword_features for more information
if not os.path.exists("./openwakeword_features_ACAV100M_2000_hrs_16bit.npy"):
    # !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy

# validation set for false positive rate estimation (~11 hours)
if not os.path.exists("validation_set_features.npy"):
    # !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy
# Out:
# fatal: destination path 'openwakeword' already exists and is not an empty directory.
# Obtaining file:///content/openwakeword
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: openwakeword
#   Building editable for openwakeword (pyproject.toml) ... done
#   Created wheel for openwakeword: filename=openwakeword-0.6.0-0.editable-py3-none-any.whl size=17481 sha256=80e8a4b4965120ebf6b8ed7dfe30dc0a44c4cc5ebc4a3b226287805ddde3d75d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j8ajy460/wheels/95/b4/6f/f887431fea7b3379ef42ac3594a92164114b83a95abb8b7969
# Successfully built openwakeword
# Installing collected packages: openwakeword
#   Attempting uninstall: openwakeword
#     Found existing installation: openwakeword 0.6.0
#     Uninstalling openwakeword-0.6.0:
#       Successfully uninstalled openwakeword-0.6.0
# Successfully installed openwakeword-0.6.0
# Requirement already satisfied: mutagen==1.47.0 in /usr/local/lib/python3.12/dist-packages (1.47.0)
# Requirement already satisfied: torchinfo==1.8.0 in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: torchmetrics==1.2.0 in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics==1.2.0) (1.26.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics==1.2.0) (2.2.0+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics==1.2.0) (0.15.3)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (26.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.25.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.1->torchmetrics==1.2.0) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.1->torchmetrics==1.2.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch>=1.8.1->torchmetrics==1.2.0) (1.3.0)
# Requirement already satisfied: speechbrain==0.5.14 in /usr/local/lib/python3.12/dist-packages (0.5.14)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (1.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (26.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (1.16.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (0.2.1)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (2.2.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (2.2.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from speechbrain==0.5.14) (0.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain==0.5.14) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9->speechbrain==0.5.14) (12.4.127)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->speechbrain==0.5.14) (1.4.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->speechbrain==0.5.14) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->speechbrain==0.5.14) (2.32.5)
# Requirement already satisfied: ruamel.yaml<0.19.0,>=0.17.28 in /usr/local/lib/python3.12/dist-packages (from hyperpyyaml->speechbrain==0.5.14) (0.18.17)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml<0.19.0,>=0.17.28->hyperpyyaml->speechbrain==0.5.14) (0.2.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9->speechbrain==0.5.14) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->speechbrain==0.5.14) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->speechbrain==0.5.14) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->speechbrain==0.5.14) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch>=1.9->speechbrain==0.5.14) (1.3.0)
# Requirement already satisfied: audiomentations==0.33.0 in /usr/local/lib/python3.12/dist-packages (0.33.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from audiomentations==0.33.0) (1.26.4)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from audiomentations==0.33.0) (0.10.2.post1)
# Requirement already satisfied: scipy<2,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from audiomentations==0.33.0) (1.16.3)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from audiomentations==0.33.0) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.1.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.9.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy-loader>=0.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (26.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.32.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2026.2.25)
# Requirement already satisfied: torch-audiomentations==0.11.0 in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations==0.11.0) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations==0.11.0) (0.10.2.post1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations==0.11.0) (2.2.0+cu121)
# Requirement already satisfied: torchaudio>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations==0.11.0) (2.2.0+cu121)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations==0.11.0) (1.2.5)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (3.1.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (4.15.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.25.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.0->torch-audiomentations==0.11.0) (12.4.127)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.12/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (1.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (26.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.32.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7.0->torch-audiomentations==0.11.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch>=1.7.0->torch-audiomentations==0.11.0) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2026.2.25)
# Requirement already satisfied: acoustics==0.2.6 in /usr/local/lib/python3.12/dist-packages (0.2.6)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.12/dist-packages (from acoustics==0.2.6) (1.26.4)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.12/dist-packages (from acoustics==0.2.6) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from acoustics==0.2.6) (3.10.0)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from acoustics==0.2.6) (1.17.0)
# Requirement already satisfied: pandas>=0.15 in /usr/local/lib/python3.12/dist-packages (from acoustics==0.2.6) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from acoustics==0.2.6) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.15->acoustics==0.2.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.15->acoustics==0.2.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.15->acoustics==0.2.6) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->acoustics==0.2.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->acoustics==0.2.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->acoustics==0.2.6) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->acoustics==0.2.6) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->acoustics==0.2.6) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->acoustics==0.2.6) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->acoustics==0.2.6) (3.3.2)
# Collecting onnxruntime==1.22.1
#   Using cached onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Collecting ai_edge_litert==1.4.0
#   Using cached ai_edge_litert-1.4.0-cp312-cp312-manylinux_2_17_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: onnxsim in /usr/local/lib/python3.12/dist-packages (0.6.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.22.1) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.22.1) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.22.1) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.22.1) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.22.1) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.22.1) (1.13.1)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert==1.4.0) (1.2.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert==1.4.0) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai_edge_litert==1.4.0) (4.15.0)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (from onnxsim) (1.19.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim) (13.9.4)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime==1.22.1) (10.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxsim) (0.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime==1.22.1) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim) (0.1.2)
# Using cached onnxruntime-1.22.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
# Using cached ai_edge_litert-1.4.0-cp312-cp312-manylinux_2_17_x86_64.whl (11.2 MB)
# Installing collected packages: ai_edge_litert, onnxruntime
#   Attempting uninstall: ai_edge_litert
#     Found existing installation: ai-edge-litert 2.1.2
#     Uninstalling ai-edge-litert-2.1.2:
#       Successfully uninstalled ai-edge-litert-2.1.2
#   Attempting uninstall: onnxruntime
#     Found existing installation: onnxruntime 1.24.3
#     Uninstalling onnxruntime-1.24.3:
#       Successfully uninstalled onnxruntime-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openwakeword 0.6.0 requires speexdsp-ns<1,>=0.1.2; platform_system == "Linux", which is not installed.
# onnx2tf 2.3.16 requires ai-edge-litert==2.1.2, but you have ai-edge-litert 1.4.0 which is incompatible.
# onnx2tf 2.3.16 requires onnx==1.20.1, but you have onnx 1.19.1 which is incompatible.
# onnx2tf 2.3.16 requires onnxruntime==1.24.3, but you have onnxruntime 1.22.1 which is incompatible.
# openwakeword 0.6.0 requires ai-edge-litert<3,>=2.0.2; platform_system == "Linux" or platform_system == "Darwin", but you have ai-edge-litert 1.4.0 which is incompatible.
# Successfully installed ai_edge_litert-1.4.0 onnxruntime-1.22.1
# Requirement already satisfied: onnx2tf in /usr/local/lib/python3.12/dist-packages (2.3.16)
# Requirement already satisfied: requests==2.32.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (2.32.5)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (1.26.4)
# Collecting onnx==1.20.1 (from onnx2tf)
#   Using cached onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Collecting onnxruntime==1.24.3 (from onnx2tf)
#   Using cached onnxruntime-1.24.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: opencv-python==4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (4.11.0.86)
# Requirement already satisfied: onnxsim-prebuilt==0.4.39.post2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (0.4.39.post2)
# Requirement already satisfied: onnxoptimizer==0.4.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (0.4.2)
# Requirement already satisfied: onnxscript==0.6.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (0.6.2)
# Collecting ai-edge-litert==2.1.2 (from onnx2tf)
#   Using cached ai_edge_litert-2.1.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: tensorflow==2.19.0 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (2.19.0)
# Requirement already satisfied: tf-keras==2.19.0 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (2.19.0)
# Requirement already satisfied: sne4onnx==2.0.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (2.0.1)
# Requirement already satisfied: sng4onnx==2.0.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (2.0.1)
# Requirement already satisfied: psutil==5.9.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (5.9.5)
# Requirement already satisfied: protobuf==4.25.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (4.25.5)
# Requirement already satisfied: h5py==3.12.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (3.12.1)
# Requirement already satisfied: ml-dtypes==0.5.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (0.5.1)
# Requirement already satisfied: flatbuffers==25.12.19 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (25.12.19)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (4.67.1)
# Requirement already satisfied: pytest==9.0.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf) (9.0.2)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2->onnx2tf) (1.2.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2->onnx2tf) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3->onnx2tf) (26.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3->onnx2tf) (1.13.1)
# Requirement already satisfied: onnx_ir<2,>=0.1.15 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.6.2->onnx2tf) (0.2.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim-prebuilt==0.4.39.post2->onnx2tf) (13.9.4)
# Requirement already satisfied: iniconfig>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf) (2026.2.25)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (1.78.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf) (3.13.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.19.0->onnx2tf) (0.46.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0->onnx2tf) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0->onnx2tf) (0.19.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime==1.24.3->onnx2tf) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf) (3.1.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim-prebuilt==0.4.39.post2->onnx2tf) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim-prebuilt==0.4.39.post2->onnx2tf) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf) (3.0.3)
# Using cached ai_edge_litert-2.1.2-cp312-cp312-manylinux_2_27_x86_64.whl (16.3 MB)
# Using cached onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.5 MB)
# Using cached onnxruntime-1.24.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.2 MB)
# Installing collected packages: ai-edge-litert, onnxruntime, onnx
#   Attempting uninstall: ai-edge-litert
#     Found existing installation: ai-edge-litert 1.4.0
#     Uninstalling ai-edge-litert-1.4.0:
#       Successfully uninstalled ai-edge-litert-1.4.0
#   Attempting uninstall: onnxruntime
#     Found existing installation: onnxruntime 1.22.1
#     Uninstalling onnxruntime-1.22.1:
#       Successfully uninstalled onnxruntime-1.22.1
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.19.1
#     Uninstalling onnx-1.19.1:
#       Successfully uninstalled onnx-1.19.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openwakeword 0.6.0 requires speexdsp-ns<1,>=0.1.2; platform_system == "Linux", which is not installed.
# Successfully installed ai-edge-litert-2.1.2 onnx-1.20.1 onnxruntime-1.24.3
# Collecting onnx==1.19.1
#   Using cached onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from onnx==1.19.1) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx==1.19.1) (4.25.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx==1.19.1) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx==1.19.1) (0.5.1)
# Using cached onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (18.2 MB)
# Installing collected packages: onnx
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.20.1
#     Uninstalling onnx-1.20.1:
#       Successfully uninstalled onnx-1.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# onnx2tf 2.3.16 requires onnx==1.20.1, but you have onnx 1.19.1 which is incompatible.
# Successfully installed onnx-1.19.1
# Requirement already satisfied: onnx_graphsurgeon in /usr/local/lib/python3.12/dist-packages (0.5.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnx_graphsurgeon) (1.26.4)
# Requirement already satisfied: onnx>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from onnx_graphsurgeon) (1.19.1)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->onnx_graphsurgeon) (4.25.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->onnx_graphsurgeon) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->onnx_graphsurgeon) (0.5.1)
# Requirement already satisfied: sng4onnx in /usr/local/lib/python3.12/dist-packages (2.0.1)
# Requirement already satisfied: pronouncing==0.2.0 in /usr/local/lib/python3.12/dist-packages (0.2.0)
# Requirement already satisfied: cmudict>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pronouncing==0.2.0) (1.1.3)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.12/dist-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (8.7.1)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.12/dist-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=5->cmudict>=0.4.0->pronouncing==0.2.0) (3.23.0)
# Requirement already satisfied: datasets==2.14.6 in /usr/local/lib/python3.12/dist-packages (2.14.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (1.26.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.14.6) (2023.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (0.36.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.14.6) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.14.6) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.14.6) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.14.6) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.14.6) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.14.6) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.14.6) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.14.6) (1.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.14.6) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.14.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.14.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->datasets==2.14.6) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.14.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.14.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.14.6) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.14.6) (1.17.0)
# Requirement already satisfied: deep-phonemizer==0.0.19 in /usr/local/lib/python3.12/dist-packages (0.0.19)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from deep-phonemizer==0.0.19) (2.2.0+cu121)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from deep-phonemizer==0.0.19) (4.67.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from deep-phonemizer==0.0.19) (6.0.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from deep-phonemizer==0.0.19) (2.19.0)
# Requirement already satisfied: certifi>=2022.12.7 in /usr/local/lib/python3.12/dist-packages (from deep-phonemizer==0.0.19) (2026.2.25)
# Requirement already satisfied: wheel>=0.38.0 in /usr/local/lib/python3.12/dist-packages (from deep-phonemizer==0.0.19) (0.46.3)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.12/dist-packages (from deep-phonemizer==0.0.19) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.2.0->deep-phonemizer==0.0.19) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.2.0->deep-phonemizer==0.0.19) (12.4.127)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from wheel>=0.38.0->deep-phonemizer==0.0.19) (26.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (4.25.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->deep-phonemizer==0.0.19) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch>=1.2.0->deep-phonemizer==0.0.19) (1.3.0)
# --2026-03-30 22:13:26--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T23%3A13%3A01Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T22%3A12%3A53Z&ske=2026-03-30T23%3A13%3A01Z&sks=b&skv=2018-11-09&sig=0qNkKanG4R1fMI4lGkq5dqJKQZMPaGwbcJ1594mGFj8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNiwibmJmIjoxNzc0OTA4ODA2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.zlfrtyWd34Jcs2PVS2t1qKzCs0Vak4mkrmz5sbQUrgw&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream [following]
# --2026-03-30 22:13:26--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T23%3A13%3A01Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T22%3A12%3A53Z&ske=2026-03-30T23%3A13%3A01Z&sks=b&skv=2018-11-09&sig=0qNkKanG4R1fMI4lGkq5dqJKQZMPaGwbcJ1594mGFj8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNiwibmJmIjoxNzc0OTA4ODA2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.zlfrtyWd34Jcs2PVS2t1qKzCs0Vak4mkrmz5sbQUrgw&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1326578 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’
#
# ./openwakeword/open 100%[===================>]   1.26M  --.-KB/s    in 0.04s
#
# 2026-03-30 22:13:26 (31.1 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’ saved [1326578/1326578]
#
# --2026-03-30 22:13:26--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T22%3A46%3A32Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T21%3A45%3A50Z&ske=2026-03-30T22%3A46%3A32Z&sks=b&skv=2018-11-09&sig=aYHdhnNSKQB80YWblV3c%2FSkTe0iJbuKIqy4IHnahtO8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNiwibmJmIjoxNzc0OTA4ODA2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.zlfrtyWd34Jcs2PVS2t1qKzCs0Vak4mkrmz5sbQUrgw&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream [following]
# --2026-03-30 22:13:26--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T22%3A46%3A32Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T21%3A45%3A50Z&ske=2026-03-30T22%3A46%3A32Z&sks=b&skv=2018-11-09&sig=aYHdhnNSKQB80YWblV3c%2FSkTe0iJbuKIqy4IHnahtO8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNiwibmJmIjoxNzc0OTA4ODA2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.zlfrtyWd34Jcs2PVS2t1qKzCs0Vak4mkrmz5sbQUrgw&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330312 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’
#
# ./openwakeword/open 100%[===================>]   1.27M  --.-KB/s    in 0.04s
#
# 2026-03-30 22:13:26 (33.8 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’ saved [1330312/1330312]
#
# --2026-03-30 22:13:27--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T22%3A58%3A12Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T21%3A57%3A19Z&ske=2026-03-30T22%3A58%3A12Z&sks=b&skv=2018-11-09&sig=znfYCkQdr34XmMVqW08ExGYjfySEYY9p6Kt6EFk4h4g%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNywibmJmIjoxNzc0OTA4ODA3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.USipFkH6GZ-WD2ejL24x64zSVMdL94y3VJPKJZ5amjA&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream [following]
# --2026-03-30 22:13:27--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T22%3A58%3A12Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T21%3A57%3A19Z&ske=2026-03-30T22%3A58%3A12Z&sks=b&skv=2018-11-09&sig=znfYCkQdr34XmMVqW08ExGYjfySEYY9p6Kt6EFk4h4g%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNywibmJmIjoxNzc0OTA4ODA3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.USipFkH6GZ-WD2ejL24x64zSVMdL94y3VJPKJZ5amjA&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1087958 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.04s
#
# 2026-03-30 22:13:27 (29.4 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’ saved [1087958/1087958]
#
# --2026-03-30 22:13:27--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T23%3A01%3A52Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T22%3A01%3A26Z&ske=2026-03-30T23%3A01%3A52Z&sks=b&skv=2018-11-09&sig=EQO%2FgqjZu2VvJgBaerIiAgUnsh2kKnshTaXeZAS85Xk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNywibmJmIjoxNzc0OTA4ODA3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.USipFkH6GZ-WD2ejL24x64zSVMdL94y3VJPKJZ5amjA&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream [following]
# --2026-03-30 22:13:27--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-30T23%3A01%3A52Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-30T22%3A01%3A26Z&ske=2026-03-30T23%3A01%3A52Z&sks=b&skv=2018-11-09&sig=EQO%2FgqjZu2VvJgBaerIiAgUnsh2kKnshTaXeZAS85Xk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NDkwOTEwNywibmJmIjoxNzc0OTA4ODA3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.USipFkH6GZ-WD2ejL24x64zSVMdL94y3VJPKJZ5amjA&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092516 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.03s
#
# 2026-03-30 22:13:28 (30.7 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’ saved [1092516/1092516]

# %%
# @title  { display-mode: "form" }
# @markdown # 3. Train the Model
# @markdown Now that you have verified your target wake word and downloaded the data,
# @markdown the last step is to adjust the training paramaters (or keep
# @markdown the defaults below) and start the training!

# @markdown Each paramater controls a different aspect of training:
# @markdown - `number_of_examples` controls how many examples of your wakeword
# @markdown are generated. The default (1,000) usually produces a good model,
# @markdown but between 30,000 and 50,000 is often the best.

# @markdown - `number_of_training_steps` controls how long to train the model.
# @markdown Similar to the number of examples, the default (10,000) usually works well
# @markdown but training longer usually helps.

# @markdown - `false_activation_penalty` controls how strongly false activations
# @markdown are penalized during the training process. Higher values can make the model
# @markdown much less likely to activate when it shouldn't, but may also cause it
# @markdown to not activate when the wake word isn't spoken clearly and there is
# @markdown background noise.

# @markdown With the default values shown below,
# @markdown this takes about 30 - 60 minutes total on the normal CPU Colab runtime.
# @markdown If you want to train on more examples or train for longer,
# @markdown try changing the runtime type to a GPU to significantly speedup
# @markdown the example generating and model training.

# @markdown When the model finishes training, you can navigate to the `my_custom_model` folder
# @markdown in the file browser on the left (click on the folder icon), and download
# @markdown the [your target wake word].onnx or  <your target wake word>.tflite files.
# @markdown You can then use these as you would any other openWakeWord model!

# Load default YAML config file for training
import yaml
config = yaml.load(open("openwakeword/examples/custom_model.yml", 'r').read(), yaml.Loader)

# Modify values in the config and save a new version
number_of_examples = 1000 # @param {type:"slider", min:100, max:50000, step:50}
number_of_training_steps = 10000  # @param {type:"slider", min:0, max:50000, step:100}
false_activation_penalty = 1500  # @param {type:"slider", min:100, max:5000, step:50}
config["target_phrase"] = [target_word]
config["model_name"] = config["target_phrase"][0].replace(" ", "_")
config["n_samples"] = number_of_examples
config["n_samples_val"] = max(500, number_of_examples//10)
config["steps"] = number_of_training_steps
config["target_accuracy"] = 0.5
config["target_recall"] = 0.25
config["output_dir"] = "./my_custom_model"
config["max_negative_weight"] = false_activation_penalty

config["background_paths"] = ['./audioset_16k', './fma']  # multiple background datasets are supported
config["false_positive_validation_data_path"] = "validation_set_features.npy"
config["feature_data_files"] = {"ACAV100M_sample": "openwakeword_features_ACAV100M_2000_hrs_16bit.npy"}

with open('my_model.yaml', 'w') as file:
    documents = yaml.dump(config, file)

# Generate clips
# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --generate_clips

# Step 2: Augment the generated clips

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --augment_clips

# Step 3: Train model

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model

# # Manually save to tflite as this doesn't work right in colab (broken in python 3.11, default in Colab as of January 2025)
# def convert_onnx_to_tflite(onnx_model_path, output_path):
#     """Converts an ONNX version of an openwakeword model to the Tensorflow tflite format."""
#     # imports
#     import onnx
#     import logging
#     import tempfile
#     from onnx_tf.backend import prepare
#     import tensorflow as tf

#     # Convert to tflite from onnx model
#     onnx_model = onnx.load(onnx_model_path)
#     tf_rep = prepare(onnx_model, device="CPU")
#     with tempfile.TemporaryDirectory() as tmp_dir:
#         tf_rep.export_graph(os.path.join(tmp_dir, "tf_model"))
#         converter = tf.lite.TFLiteConverter.from_saved_model(os.path.join(tmp_dir, "tf_model"))
#         tflite_model = converter.convert()

#         logging.info(f"####\nSaving tflite mode to '{output_path}'")
#         with open(output_path, 'wb') as f:
#             f.write(tflite_model)

#     return None

# convert_onnx_to_tflite(f"my_custom_model/{config['model_name']}.onnx", f"my_custom_model/{config['model_name']}.tflite")

# Convert ONNX model to tflite using `onnx2tf` library (works for python 3.11 as of January 2025)
onnx_model_path = f"my_custom_model/{config['model_name']}.onnx"
name1, name2 = f"my_custom_model/{config['model_name']}_float32.tflite", f"my_custom_model/{config['model_name']}.tflite"
# !onnx2tf -i {onnx_model_path} -o my_custom_model/ -kat onnx____Flatten_0
# !mv {name1} {name2}

# Automatically download the trained model files
from google.colab import files

files.download(f"my_custom_model/{config['model_name']}.onnx")
files.download(f"my_custom_model/{config['model_name']}.tflite")
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# torchvision is not available - cannot save figures
# INFO:root:##################################################
# Generating positive clips for training
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:Batch 1/20 complete
# DEBUG:generate_samples:Batch 2/20 complete
# DEBUG:generate_samples:Batch 3/20 complete
# DEBUG:generate_samples:Batch 4/20 complete
# DEBUG:generate_samples:Batch 5/20 complete
# DEBUG:generate_samples:Batch 6/20 complete
# DEBUG:generate_samples:Batch 7/20 complete
# DEBUG:generate_samples:Batch 8/20 complete
# DEBUG:generate_samples:Batch 9/20 complete
# DEBUG:generate_samples:Batch 10/20 complete
# DEBUG:generate_samples:Batch 11/20 complete
# DEBUG:generate_samples:Batch 12/20 complete
# DEBUG:generate_samples:Batch 13/20 complete
# DEBUG:generate_samples:Batch 14/20 complete
# DEBUG:generate_samples:Batch 15/20 complete
# DEBUG:generate_samples:Batch 16/20 complete
# DEBUG:generate_samples:Batch 17/20 complete
# DEBUG:generate_samples:Batch 18/20 complete
# DEBUG:generate_samples:Batch 19/20 complete
# DEBUG:generate_samples:Batch 20/20 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating positive clips for testing
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:Batch 1/10 complete
# DEBUG:generate_samples:Batch 2/10 complete
# DEBUG:generate_samples:Batch 3/10 complete
# DEBUG:generate_samples:Batch 4/10 complete
# DEBUG:generate_samples:Batch 5/10 complete
# DEBUG:generate_samples:Batch 6/10 complete
# DEBUG:generate_samples:Batch 7/10 complete
# DEBUG:generate_samples:Batch 8/10 complete
# DEBUG:generate_samples:Batch 9/10 complete
# DEBUG:generate_samples:Batch 10/10 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for training
# ##################################################
# WARNING:root:Downloading phonemizer model from DeepPhonemizer library...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-asai-dl-models.s3.eu-central-1.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://public-asai-dl-models.s3.eu-central-1.amazonaws.com:443 "GET /DeepPhonemizer/en_us_cmudict_forward.pt HTTP/1.1" 200 66725366
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# DEBUG:dp.phonemizer:Initializing phonemizer with model step 1120000
# WARNING:root:The word 'dayn_jer' was not found in the pronunciation dictionary! Using the DeepPhonemizer library to predict the phonemes.
# WARNING:root:Phones for 'dayn_jer': [D][EY][N][JH][ER]
# WARNING:root:The word 'di_tected' was not found in the pronunciation dictionary! Using the DeepPhonemizer library to predict the phonemes.
# WARNING:root:Phones for 'di_tected': [D][IH][T][EH][K][T][AH][D]
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:Batch 1/142 complete
# DEBUG:generate_samples:Batch 2/142 complete
# DEBUG:generate_samples:Batch 3/142 complete
# DEBUG:generate_samples:Batch 4/142 complete
# DEBUG:generate_samples:Batch 5/142 complete
# DEBUG:generate_samples:Batch 6/142 complete
# DEBUG:generate_samples:Batch 7/142 complete
# DEBUG:generate_samples:Batch 8/142 complete
# DEBUG:generate_samples:Batch 9/142 complete
# DEBUG:generate_samples:Batch 10/142 complete
# DEBUG:generate_samples:Batch 11/142 complete
# DEBUG:generate_samples:Batch 12/142 complete
# DEBUG:generate_samples:Batch 13/142 complete
# DEBUG:generate_samples:Batch 14/142 complete
# DEBUG:generate_samples:Batch 15/142 complete
# DEBUG:generate_samples:Batch 16/142 complete
# DEBUG:generate_samples:Batch 17/142 complete
# DEBUG:generate_samples:Batch 18/142 complete
# DEBUG:generate_samples:Batch 19/142 complete
# DEBUG:generate_samples:Batch 20/142 complete
# DEBUG:generate_samples:Batch 21/142 complete
# DEBUG:generate_samples:Batch 22/142 complete
# DEBUG:generate_samples:Batch 23/142 complete
# DEBUG:generate_samples:Batch 24/142 complete
# DEBUG:generate_samples:Batch 25/142 complete
# DEBUG:generate_samples:Batch 26/142 complete
# DEBUG:generate_samples:Batch 27/142 complete
# DEBUG:generate_samples:Batch 28/142 complete
# DEBUG:generate_samples:Batch 29/142 complete
# DEBUG:generate_samples:Batch 30/142 complete
# DEBUG:generate_samples:Batch 31/142 complete
# DEBUG:generate_samples:Batch 32/142 complete
# DEBUG:generate_samples:Batch 33/142 complete
# DEBUG:generate_samples:Batch 34/142 complete
# DEBUG:generate_samples:Batch 35/142 complete
# DEBUG:generate_samples:Batch 36/142 complete
# DEBUG:generate_samples:Batch 37/142 complete
# DEBUG:generate_samples:Batch 38/142 complete
# DEBUG:generate_samples:Batch 39/142 complete
# DEBUG:generate_samples:Batch 40/142 complete
# DEBUG:generate_samples:Batch 41/142 complete
# DEBUG:generate_samples:Batch 42/142 complete
# DEBUG:generate_samples:Batch 43/142 complete
# DEBUG:generate_samples:Batch 44/142 complete
# DEBUG:generate_samples:Batch 45/142 complete
# DEBUG:generate_samples:Batch 46/142 complete
# DEBUG:generate_samples:Batch 47/142 complete
# DEBUG:generate_samples:Batch 48/142 complete
# DEBUG:generate_samples:Batch 49/142 complete
# DEBUG:generate_samples:Batch 50/142 complete
# DEBUG:generate_samples:Batch 51/142 complete
# DEBUG:generate_samples:Batch 52/142 complete
# DEBUG:generate_samples:Batch 53/142 complete
# DEBUG:generate_samples:Batch 54/142 complete
# DEBUG:generate_samples:Batch 55/142 complete
# DEBUG:generate_samples:Batch 56/142 complete
# DEBUG:generate_samples:Batch 57/142 complete
# DEBUG:generate_samples:Batch 58/142 complete
# DEBUG:generate_samples:Batch 59/142 complete
# DEBUG:generate_samples:Batch 60/142 complete
# DEBUG:generate_samples:Batch 61/142 complete
# DEBUG:generate_samples:Batch 62/142 complete
# DEBUG:generate_samples:Batch 63/142 complete
# DEBUG:generate_samples:Batch 64/142 complete
# DEBUG:generate_samples:Batch 65/142 complete
# DEBUG:generate_samples:Batch 66/142 complete
# DEBUG:generate_samples:Batch 67/142 complete
# DEBUG:generate_samples:Batch 68/142 complete
# DEBUG:generate_samples:Batch 69/142 complete
# DEBUG:generate_samples:Batch 70/142 complete
# DEBUG:generate_samples:Batch 71/142 complete
# DEBUG:generate_samples:Batch 72/142 complete
# DEBUG:generate_samples:Batch 73/142 complete
# DEBUG:generate_samples:Batch 74/142 complete
# DEBUG:generate_samples:Batch 75/142 complete
# DEBUG:generate_samples:Batch 76/142 complete
# DEBUG:generate_samples:Batch 77/142 complete
# DEBUG:generate_samples:Batch 78/142 complete
# DEBUG:generate_samples:Batch 79/142 complete
# DEBUG:generate_samples:Batch 80/142 complete
# DEBUG:generate_samples:Batch 81/142 complete
# DEBUG:generate_samples:Batch 82/142 complete
# DEBUG:generate_samples:Batch 83/142 complete
# DEBUG:generate_samples:Batch 84/142 complete
# DEBUG:generate_samples:Batch 85/142 complete
# DEBUG:generate_samples:Batch 86/142 complete
# DEBUG:generate_samples:Batch 87/142 complete
# DEBUG:generate_samples:Batch 88/142 complete
# DEBUG:generate_samples:Batch 89/142 complete
# DEBUG:generate_samples:Batch 90/142 complete
# DEBUG:generate_samples:Batch 91/142 complete
# DEBUG:generate_samples:Batch 92/142 complete
# DEBUG:generate_samples:Batch 93/142 complete
# DEBUG:generate_samples:Batch 94/142 complete
# DEBUG:generate_samples:Batch 95/142 complete
# DEBUG:generate_samples:Batch 96/142 complete
# DEBUG:generate_samples:Batch 97/142 complete
# DEBUG:generate_samples:Batch 98/142 complete
# DEBUG:generate_samples:Batch 99/142 complete
# DEBUG:generate_samples:Batch 100/142 complete
# DEBUG:generate_samples:Batch 101/142 complete
# DEBUG:generate_samples:Batch 102/142 complete
# DEBUG:generate_samples:Batch 103/142 complete
# DEBUG:generate_samples:Batch 104/142 complete
# DEBUG:generate_samples:Batch 105/142 complete
# DEBUG:generate_samples:Batch 106/142 complete
# DEBUG:generate_samples:Batch 107/142 complete
# DEBUG:generate_samples:Batch 108/142 complete
# DEBUG:generate_samples:Batch 109/142 complete
# DEBUG:generate_samples:Batch 110/142 complete
# DEBUG:generate_samples:Batch 111/142 complete
# DEBUG:generate_samples:Batch 112/142 complete
# DEBUG:generate_samples:Batch 113/142 complete
# DEBUG:generate_samples:Batch 114/142 complete
# DEBUG:generate_samples:Batch 115/142 complete
# DEBUG:generate_samples:Batch 116/142 complete
# DEBUG:generate_samples:Batch 117/142 complete
# DEBUG:generate_samples:Batch 118/142 complete
# DEBUG:generate_samples:Batch 119/142 complete
# DEBUG:generate_samples:Batch 120/142 complete
# DEBUG:generate_samples:Batch 121/142 complete
# DEBUG:generate_samples:Batch 122/142 complete
# DEBUG:generate_samples:Batch 123/142 complete
# DEBUG:generate_samples:Batch 124/142 complete
# DEBUG:generate_samples:Batch 125/142 complete
# DEBUG:generate_samples:Batch 126/142 complete
# DEBUG:generate_samples:Batch 127/142 complete
# DEBUG:generate_samples:Batch 128/142 complete
# DEBUG:generate_samples:Batch 129/142 complete
# DEBUG:generate_samples:Batch 130/142 complete
# DEBUG:generate_samples:Batch 131/142 complete
# DEBUG:generate_samples:Batch 132/142 complete
# DEBUG:generate_samples:Batch 133/142 complete
# DEBUG:generate_samples:Batch 134/142 complete
# DEBUG:generate_samples:Batch 135/142 complete
# DEBUG:generate_samples:Batch 136/142 complete
# DEBUG:generate_samples:Batch 137/142 complete
# DEBUG:generate_samples:Batch 138/142 complete
# DEBUG:generate_samples:Batch 139/142 complete
# DEBUG:generate_samples:Batch 140/142 complete
# DEBUG:generate_samples:Batch 141/142 complete
# DEBUG:generate_samples:Batch 142/142 complete
# DEBUG:generate_samples:Batch 143/142 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for testing
# ##################################################
# DEBUG:dp.phonemizer:Initializing phonemizer with model step 1120000
# WARNING:root:The word 'dayn_jer' was not found in the pronunciation dictionary! Using the DeepPhonemizer library to predict the phonemes.
# WARNING:root:Phones for 'dayn_jer': [D][EY][N][JH][ER]
# WARNING:root:The word 'di_tected' was not found in the pronunciation dictionary! Using the DeepPhonemizer library to predict the phonemes.
# WARNING:root:Phones for 'di_tected': [D][IH][T][EH][K][T][AH][D]
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:Batch 1/71 complete
# DEBUG:generate_samples:Batch 2/71 complete
# DEBUG:generate_samples:Batch 3/71 complete
# DEBUG:generate_samples:Batch 4/71 complete
# DEBUG:generate_samples:Batch 5/71 complete
# DEBUG:generate_samples:Batch 6/71 complete
# DEBUG:generate_samples:Batch 7/71 complete
# DEBUG:generate_samples:Batch 8/71 complete
# DEBUG:generate_samples:Batch 9/71 complete
# DEBUG:generate_samples:Batch 10/71 complete
# DEBUG:generate_samples:Batch 11/71 complete
# DEBUG:generate_samples:Batch 12/71 complete
# DEBUG:generate_samples:Batch 13/71 complete
# DEBUG:generate_samples:Batch 14/71 complete
# DEBUG:generate_samples:Batch 15/71 complete
# DEBUG:generate_samples:Batch 16/71 complete
# DEBUG:generate_samples:Batch 17/71 complete
# DEBUG:generate_samples:Batch 18/71 complete
# DEBUG:generate_samples:Batch 19/71 complete
# DEBUG:generate_samples:Batch 20/71 complete
# DEBUG:generate_samples:Batch 21/71 complete
# DEBUG:generate_samples:Batch 22/71 complete
# DEBUG:generate_samples:Batch 23/71 complete
# DEBUG:generate_samples:Batch 24/71 complete
# DEBUG:generate_samples:Batch 25/71 complete
# DEBUG:generate_samples:Batch 26/71 complete
# DEBUG:generate_samples:Batch 27/71 complete
# DEBUG:generate_samples:Batch 28/71 complete
# DEBUG:generate_samples:Batch 29/71 complete
# DEBUG:generate_samples:Batch 30/71 complete
# DEBUG:generate_samples:Batch 31/71 complete
# DEBUG:generate_samples:Batch 32/71 complete
# DEBUG:generate_samples:Batch 33/71 complete
# DEBUG:generate_samples:Batch 34/71 complete
# DEBUG:generate_samples:Batch 35/71 complete
# DEBUG:generate_samples:Batch 36/71 complete
# DEBUG:generate_samples:Batch 37/71 complete
# DEBUG:generate_samples:Batch 38/71 complete
# DEBUG:generate_samples:Batch 39/71 complete
# DEBUG:generate_samples:Batch 40/71 complete
# DEBUG:generate_samples:Batch 41/71 complete
# DEBUG:generate_samples:Batch 42/71 complete
# DEBUG:generate_samples:Batch 43/71 complete
# DEBUG:generate_samples:Batch 44/71 complete
# DEBUG:generate_samples:Batch 45/71 complete
# DEBUG:generate_samples:Batch 46/71 complete
# DEBUG:generate_samples:Batch 47/71 complete
# DEBUG:generate_samples:Batch 48/71 complete
# DEBUG:generate_samples:Batch 49/71 complete
# DEBUG:generate_samples:Batch 50/71 complete
# DEBUG:generate_samples:Batch 51/71 complete
# DEBUG:generate_samples:Batch 52/71 complete
# DEBUG:generate_samples:Batch 53/71 complete
# DEBUG:generate_samples:Batch 54/71 complete
# DEBUG:generate_samples:Batch 55/71 complete
# DEBUG:generate_samples:Batch 56/71 complete
# DEBUG:generate_samples:Batch 57/71 complete
# DEBUG:generate_samples:Batch 58/71 complete
# DEBUG:generate_samples:Batch 59/71 complete
# DEBUG:generate_samples:Batch 60/71 complete
# DEBUG:generate_samples:Batch 61/71 complete
# DEBUG:generate_samples:Batch 62/71 complete
# DEBUG:generate_samples:Batch 63/71 complete
# DEBUG:generate_samples:Batch 64/71 complete
# DEBUG:generate_samples:Batch 65/71 complete
# DEBUG:generate_samples:Batch 66/71 complete
# DEBUG:generate_samples:Batch 67/71 complete
# DEBUG:generate_samples:Batch 68/71 complete
# DEBUG:generate_samples:Batch 69/71 complete
# DEBUG:generate_samples:Batch 70/71 complete
# DEBUG:generate_samples:Batch 71/71 complete
# DEBUG:generate_samples:Batch 72/71 complete
# INFO:generate_samples:Done
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# torchvision is not available - cannot save figures
# INFO:root:##################################################
# Computing openwakeword features for generated samples
# ##################################################
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/core/transforms_interface.py:77: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = PitchShift(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/core/transforms_interface.py:77: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = BandStopFilter(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/core/transforms_interface.py:77: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddColoredNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/core/transforms_interface.py:77: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddBackgroundNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/core/transforms_interface.py:77: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Gain(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/core/composition.py:42: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Compose(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/audiomentations/core/transforms_interface.py:61: UserWarning: Warning: input samples dtype is np.float64. Converting to np.float32
#   warnings.warn(
# Computing features: 100% 62/62 [01:46<00:00,  1.72s/it]
# Trimming empty rows: 1it [00:00, 36.59it/s]
# Computing features: 100% 62/62 [01:39<00:00,  1.60s/it]
# Trimming empty rows: 1it [00:00, 33.33it/s]
# Computing features: 100% 31/31 [00:57<00:00,  1.86s/it]
# Trimming empty rows: 1it [00:00, 57.13it/s]
# Computing features: 100% 31/31 [00:47<00:00,  1.53s/it]
# Trimming empty rows: 1it [00:00, 57.55it/s]
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# torchvision is not available - cannot save figures
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 733, in _resolve_func_scope_forward_hint
#     hint_resolved = eval(hint, decor_meta.func_wrappee_scope_forward)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# AttributeError: module 'onnxscript.values' has no attribute 'ParamSchema'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/openwakeword/openwakeword/train.py", line 825, in <module>
#     oww = Model(n_classes=1, input_shape=input_shape, model_type=config["model_type"],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/openwakeword/openwakeword/train.py", line 135, in __init__
#     self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/adam.py", line 45, in __init__
#     super().__init__(params, defaults)
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 278, in __init__
#     self.add_param_group(cast(dict, param_group))
#   File "/usr/local/lib/python3.12/dist-packages/torch/_compile.py", line 22, in inner
#     import torch._dynamo
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/__init__.py", line 2, in <module>
#     from . import allowed_functions, convert_frame, eval_frame, resume_execution
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/convert_frame.py", line 45, in <module>
#     from .eval_frame import always_optimize_code_objects, skip_code, TorchPatcher
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 69, in <module>
#     from . import config, convert_frame, external_utils, skipfiles, utils
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/skipfiles.py", line 39, in <module>
#     from .variables.functions import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/__init__.py", line 26, in <module>
#     from .higher_order_ops import TorchHigherOrderOperatorVariable
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/higher_order_ops.py", line 11, in <module>
#     import torch.onnx.operators
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/__init__.py", line 59, in <module>
#     from ._internal.onnxruntime import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/onnxruntime.py", line 48, in <module>
#     from torch.onnx._internal.fx import fx_onnx_interpreter
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/fx/fx_onnx_interpreter.py", line 19, in <module>
#     from torch.onnx._internal.fx import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/fx/op_validation.py", line 301, in <module>
#     @_beartype.beartype
#      ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/decorcache.py", line 100, in beartype
#     return beartype_object(obj, conf)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/decorcore.py", line 83, in beartype_object
#     _beartype_object_fatal(obj, conf=conf, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/decorcore.py", line 133, in _beartype_object_fatal
#     beartype_nontype(obj, **kwargs)  # type: ignore[return-value]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/decornontype.py", line 313, in beartype_nontype
#     return beartype_func(obj, **kwargs)  # type: ignore[return-value]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/decornontype.py", line 402, in beartype_func
#     func_wrapper_code = generate_code(decor_meta)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/_wrap/wrapmain.py", line 121, in generate_code
#     code_check_params = _code_check_args(decor_meta)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/_wrap/_wrapargs.py", line 423, in code_check_args
#     reraise_exception_placeholder(
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_util/error/utilerrraise.py", line 138, in reraise_exception_placeholder
#     raise exception.with_traceback(exception.__traceback__)
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/_wrap/_wrapargs.py", line 263, in code_check_args
#     hint_sane = sanify_hint_root_func(
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/convert/convmain.py", line 143, in sanify_hint_root_func
#     hint_coerced = coerce_func_hint_root(
#                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/convert/_convcoerce.py", line 132, in coerce_func_hint_root
#     hint = resolve_hint(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 300, in resolve_hint
#     return _resolve_func_scope_forward_hint(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 766, in _resolve_func_scope_forward_hint
#     raise exception_cls(exception_message) from exception
# beartype.roar.BeartypeDecorHintForwardRefException: Function torch.onnx._internal.fx.op_validation._convert_torch_args_to_onnxfunction_args() parameter "param_schemas" stringified type hint 'Sequence[onnxscript.values.ParamSchema]' invalid, as attempting to dynamically import the attribute referred to by this hint raises:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 733, in _resolve_func_scope_forward_hint
#     hint_resolved = eval(hint, decor_meta.func_wrappee_scope_forward)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# AttributeError: module 'onnxscript.values' has no attribute 'ParamSchema'
#
# ERROR: The specified *.onnx file does not exist. input_onnx_file_path: my_custom_model/dayn_jer_di_tected.onnx
# mv: cannot stat 'my_custom_model/dayn_jer_di_tected_float32.tflite': No such file or directory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_38433/3117315244.py in <cell line: 0>()
#     102 from google.colab import files
#     103
# --> 104 files.download(f"my_custom_model/{config['model_name']}.onnx")
#     105 files.download(f"my_custom_model/{config['model_name']}.tflite")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: my_custom_model/dayn_jer_di_tected.onnx

# %%
# Repair the ONNX / ONNXScript environment for openWakeWord training
# !pip uninstall -y onnxscript onnx onnxruntime ai-edge-litert onnx2tf onnx_graphsurgeon

# !pip install onnx==1.20.1
# !pip install onnxruntime==1.24.3
# !pip install ai-edge-litert==2.1.2
# !pip install onnxscript==0.5.4
# !pip install onnx2tf==2.3.16
# !pip install onnx_graphsurgeon
# !pip install speexdsp-ns==0.1.2
# Out:
# Found existing installation: onnxscript 0.6.2
# Uninstalling onnxscript-0.6.2:
#   Successfully uninstalled onnxscript-0.6.2
# Found existing installation: onnx 1.19.1
# Uninstalling onnx-1.19.1:
#   Successfully uninstalled onnx-1.19.1
# Found existing installation: onnxruntime 1.24.3
# Uninstalling onnxruntime-1.24.3:
#   Successfully uninstalled onnxruntime-1.24.3
# Found existing installation: ai-edge-litert 2.1.2
# Uninstalling ai-edge-litert-2.1.2:
#   Successfully uninstalled ai-edge-litert-2.1.2
# Found existing installation: onnx2tf 2.3.16
# Uninstalling onnx2tf-2.3.16:
#   Successfully uninstalled onnx2tf-2.3.16
# Found existing installation: onnx_graphsurgeon 0.5.8
# Uninstalling onnx_graphsurgeon-0.5.8:
#   Successfully uninstalled onnx_graphsurgeon-0.5.8
# Collecting onnx==1.20.1
#   Using cached onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx==1.20.1) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx==1.20.1) (4.25.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx==1.20.1) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx==1.20.1) (0.5.1)
# Using cached onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.5 MB)
# Installing collected packages: onnx
# Successfully installed onnx-1.20.1
# Collecting onnxruntime==1.24.3
#   Using cached onnxruntime-1.24.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime==1.24.3) (1.3.0)
# Using cached onnxruntime-1.24.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.2 MB)
# Installing collected packages: onnxruntime
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openwakeword 0.6.0 requires ai-edge-litert<3,>=2.0.2; platform_system == "Linux" or platform_system == "Darwin", which is not installed.
# openwakeword 0.6.0 requires speexdsp-ns<1,>=0.1.2; platform_system == "Linux", which is not installed.
# Successfully installed onnxruntime-1.24.3
# Collecting ai-edge-litert==2.1.2
#   Using cached ai_edge_litert-2.1.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2) (1.2.8)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2) (25.12.19)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2) (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2) (4.15.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2) (4.25.5)
# Using cached ai_edge_litert-2.1.2-cp312-cp312-manylinux_2_27_x86_64.whl (16.3 MB)
# Installing collected packages: ai-edge-litert
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openwakeword 0.6.0 requires speexdsp-ns<1,>=0.1.2; platform_system == "Linux", which is not installed.
# Successfully installed ai-edge-litert-2.1.2
# Collecting onnxscript==0.5.4
#   Downloading onnxscript-0.5.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (0.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (1.26.4)
# Requirement already satisfied: onnx_ir<2,>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (0.2.0)
# Requirement already satisfied: onnx>=1.16 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (1.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (26.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.16->onnxscript==0.5.4) (4.25.5)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.10->onnxscript==0.5.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.10->onnxscript==0.5.4) (1.3.0)
# Downloading onnxscript-0.5.4-py3-none-any.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.3/679.3 kB 14.1 MB/s eta 0:00:00
# Installing collected packages: onnxscript
# Successfully installed onnxscript-0.5.4
# Collecting onnx2tf==2.3.16
#   Using cached onnx2tf-2.3.16-py3-none-any.whl.metadata (223 kB)
# Requirement already satisfied: requests==2.32.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.32.5)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (1.26.4)
# Requirement already satisfied: onnx==1.20.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (1.20.1)
# Requirement already satisfied: onnxruntime==1.24.3 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (1.24.3)
# Requirement already satisfied: opencv-python==4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (4.11.0.86)
# Requirement already satisfied: onnxsim-prebuilt==0.4.39.post2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (0.4.39.post2)
# Requirement already satisfied: onnxoptimizer==0.4.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (0.4.2)
# Collecting onnxscript==0.6.2 (from onnx2tf==2.3.16)
#   Using cached onnxscript-0.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ai-edge-litert==2.1.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.1.2)
# Requirement already satisfied: tensorflow==2.19.0 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.19.0)
# Requirement already satisfied: tf-keras==2.19.0 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.19.0)
# Requirement already satisfied: sne4onnx==2.0.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.0.1)
# Requirement already satisfied: sng4onnx==2.0.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.0.1)
# Requirement already satisfied: psutil==5.9.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (5.9.5)
# Requirement already satisfied: protobuf==4.25.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (4.25.5)
# Requirement already satisfied: h5py==3.12.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (3.12.1)
# Requirement already satisfied: ml-dtypes==0.5.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (0.5.1)
# Requirement already satisfied: flatbuffers==25.12.19 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (25.12.19)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (4.67.1)
# Requirement already satisfied: pytest==9.0.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (9.0.2)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2->onnx2tf==2.3.16) (1.2.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2->onnx2tf==2.3.16) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3->onnx2tf==2.3.16) (26.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3->onnx2tf==2.3.16) (1.13.1)
# Requirement already satisfied: onnx_ir<2,>=0.1.15 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.6.2->onnx2tf==2.3.16) (0.2.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim-prebuilt==0.4.39.post2->onnx2tf==2.3.16) (13.9.4)
# Requirement already satisfied: iniconfig>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf==2.3.16) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf==2.3.16) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf==2.3.16) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (2026.2.25)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.78.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (3.13.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.46.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.19.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime==1.24.3->onnx2tf==2.3.16) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (3.1.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim-prebuilt==0.4.39.post2->onnx2tf==2.3.16) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim-prebuilt==0.4.39.post2->onnx2tf==2.3.16) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (3.0.3)
# Using cached onnx2tf-2.3.16-py3-none-any.whl (1.9 MB)
# Using cached onnxscript-0.6.2-py3-none-any.whl (689 kB)
# Installing collected packages: onnxscript, onnx2tf
#   Attempting uninstall: onnxscript
#     Found existing installation: onnxscript 0.5.4
#     Uninstalling onnxscript-0.5.4:
#       Successfully uninstalled onnxscript-0.5.4
# Successfully installed onnx2tf-2.3.16 onnxscript-0.6.2
# Collecting onnx_graphsurgeon
#   Using cached onnx_graphsurgeon-0.5.8-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnx_graphsurgeon) (1.26.4)
# Requirement already satisfied: onnx>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from onnx_graphsurgeon) (1.20.1)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->onnx_graphsurgeon) (4.25.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->onnx_graphsurgeon) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->onnx_graphsurgeon) (0.5.1)
# Using cached onnx_graphsurgeon-0.5.8-py2.py3-none-any.whl (57 kB)
# Installing collected packages: onnx_graphsurgeon
# Successfully installed onnx_graphsurgeon-0.5.8
# Collecting speexdsp-ns==0.1.2
#   Downloading speexdsp_ns-0.1.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading speexdsp_ns-0.1.2-cp312-cp312-manylinux_2_28_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.6/161.6 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: speexdsp-ns
# Successfully installed speexdsp-ns-0.1.2

# %%
# Retry only the training stage
# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# torchvision is not available - cannot save figures
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 733, in _resolve_func_scope_forward_hint
#     hint_resolved = eval(hint, decor_meta.func_wrappee_scope_forward)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# AttributeError: module 'onnxscript.values' has no attribute 'ParamSchema'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/openwakeword/openwakeword/train.py", line 825, in <module>
#     oww = Model(n_classes=1, input_shape=input_shape, model_type=config["model_type"],
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/openwakeword/openwakeword/train.py", line 135, in __init__
#     self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/adam.py", line 45, in __init__
#     super().__init__(params, defaults)
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 278, in __init__
#     self.add_param_group(cast(dict, param_group))
#   File "/usr/local/lib/python3.12/dist-packages/torch/_compile.py", line 22, in inner
#     import torch._dynamo
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/__init__.py", line 2, in <module>
#     from . import allowed_functions, convert_frame, eval_frame, resume_execution
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/convert_frame.py", line 45, in <module>
#     from .eval_frame import always_optimize_code_objects, skip_code, TorchPatcher
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 69, in <module>
#     from . import config, convert_frame, external_utils, skipfiles, utils
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/skipfiles.py", line 39, in <module>
#     from .variables.functions import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/__init__.py", line 26, in <module>
#     from .higher_order_ops import TorchHigherOrderOperatorVariable
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/variables/higher_order_ops.py", line 11, in <module>
#     import torch.onnx.operators
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/__init__.py", line 59, in <module>
#     from ._internal.onnxruntime import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/onnxruntime.py", line 48, in <module>
#     from torch.onnx._internal.fx import fx_onnx_interpreter
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/fx/fx_onnx_interpreter.py", line 19, in <module>
#     from torch.onnx._internal.fx import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/fx/op_validation.py", line 301, in <module>
#     @_beartype.beartype
#      ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/decorcache.py", line 100, in beartype
#     return beartype_object(obj, conf)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/decorcore.py", line 83, in beartype_object
#     _beartype_object_fatal(obj, conf=conf, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/decorcore.py", line 133, in _beartype_object_fatal
#     beartype_nontype(obj, **kwargs)  # type: ignore[return-value]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/decornontype.py", line 313, in beartype_nontype
#     return beartype_func(obj, **kwargs)  # type: ignore[return-value]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/decornontype.py", line 402, in beartype_func
#     func_wrapper_code = generate_code(decor_meta)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/_wrap/wrapmain.py", line 121, in generate_code
#     code_check_params = _code_check_args(decor_meta)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/_wrap/_wrapargs.py", line 423, in code_check_args
#     reraise_exception_placeholder(
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_util/error/utilerrraise.py", line 138, in reraise_exception_placeholder
#     raise exception.with_traceback(exception.__traceback__)
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_decor/_nontype/_wrap/_wrapargs.py", line 263, in code_check_args
#     hint_sane = sanify_hint_root_func(
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/convert/convmain.py", line 143, in sanify_hint_root_func
#     hint_coerced = coerce_func_hint_root(
#                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/convert/_convcoerce.py", line 132, in coerce_func_hint_root
#     hint = resolve_hint(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 300, in resolve_hint
#     return _resolve_func_scope_forward_hint(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 766, in _resolve_func_scope_forward_hint
#     raise exception_cls(exception_message) from exception
# beartype.roar.BeartypeDecorHintForwardRefException: Function torch.onnx._internal.fx.op_validation._convert_torch_args_to_onnxfunction_args() parameter "param_schemas" stringified type hint 'Sequence[onnxscript.values.ParamSchema]' invalid, as attempting to dynamically import the attribute referred to by this hint raises:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/beartype/_check/forward/fwdresolve.py", line 733, in _resolve_func_scope_forward_hint
#     hint_resolved = eval(hint, decor_meta.func_wrappee_scope_forward)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# AttributeError: module 'onnxscript.values' has no attribute 'ParamSchema'

# %%
# Remove only the conversion-related packages that are re-breaking training
# !pip uninstall -y onnx2tf onnxscript onnx_graphsurgeon

# Reinstall the older onnxscript version needed for training
# !pip install onnxscript==0.5.4
# Out:
# Found existing installation: onnx2tf 2.3.16
# Uninstalling onnx2tf-2.3.16:
#   Successfully uninstalled onnx2tf-2.3.16
# Found existing installation: onnxscript 0.6.2
# Uninstalling onnxscript-0.6.2:
#   Successfully uninstalled onnxscript-0.6.2
# Found existing installation: onnx_graphsurgeon 0.5.8
# Uninstalling onnx_graphsurgeon-0.5.8:
#   Successfully uninstalled onnx_graphsurgeon-0.5.8
# Collecting onnxscript==0.5.4
#   Using cached onnxscript-0.5.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (0.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (1.26.4)
# Requirement already satisfied: onnx_ir<2,>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (0.2.0)
# Requirement already satisfied: onnx>=1.16 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (1.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (26.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.5.4) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.16->onnxscript==0.5.4) (4.25.5)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.10->onnxscript==0.5.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.10->onnxscript==0.5.4) (1.3.0)
# Using cached onnxscript-0.5.4-py3-none-any.whl (679 kB)
# Installing collected packages: onnxscript
# Successfully installed onnxscript-0.5.4

# %%
# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# torchvision is not available - cannot save figures
# INFO:root:##################################################
# Starting training sequence 1...
# ##################################################
# Training: 100% 9999/10000 [09:15<00:00, 18.02it/s]
# INFO:root:##################################################
# Starting training sequence 2...
# ##################################################
# INFO:root:Increasing weight on negative examples to reduce false positives...
# Training: 100% 999/1000.0 [03:51<00:00,  4.31it/s]
# INFO:root:##################################################
# Starting training sequence 3...
# ##################################################
# INFO:root:Increasing weight on negative examples to reduce false positives...
# Training: 100% 999/1000.0 [03:47<00:00,  4.38it/s]
# INFO:root:Merging checkpoints above the 90th percentile into single model...
# INFO:root:
# ################
# Final Model Accuracy: 0.6819999814033508
# Final Model Recall: 0.3659999966621399
# Final Model False Positives per Hour: 1.1504424810409546
# ################
#
# INFO:root:####
# Saving ONNX mode as '/content/my_custom_model/dayn_jer_di_tected.onnx'
# Traceback (most recent call last):
#   File "/content/openwakeword/openwakeword/train.py", line 909, in <module>
#     convert_onnx_to_tflite(os.path.join(config["output_dir"], config["model_name"] + ".onnx"),
#   File "/content/openwakeword/openwakeword/train.py", line 578, in convert_onnx_to_tflite
#     from onnx_tf.backend import prepare
# ModuleNotFoundError: No module named 'onnx_tf'

# %%
import os
print(os.path.exists("/content/my_custom_model/dayn_jer_di_tected.onnx"))
# Out:
# True

# %%
# !pip install onnx2tf==2.3.16 onnx_graphsurgeon
# Out:
# Collecting onnx2tf==2.3.16
#   Using cached onnx2tf-2.3.16-py3-none-any.whl.metadata (223 kB)
# Collecting onnx_graphsurgeon
#   Using cached onnx_graphsurgeon-0.5.8-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: requests==2.32.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.32.5)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (1.26.4)
# Requirement already satisfied: onnx==1.20.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (1.20.1)
# Requirement already satisfied: onnxruntime==1.24.3 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (1.24.3)
# Requirement already satisfied: opencv-python==4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (4.11.0.86)
# Requirement already satisfied: onnxsim-prebuilt==0.4.39.post2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (0.4.39.post2)
# Requirement already satisfied: onnxoptimizer==0.4.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (0.4.2)
# Collecting onnxscript==0.6.2 (from onnx2tf==2.3.16)
#   Using cached onnxscript-0.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ai-edge-litert==2.1.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.1.2)
# Requirement already satisfied: tensorflow==2.19.0 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.19.0)
# Requirement already satisfied: tf-keras==2.19.0 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.19.0)
# Requirement already satisfied: sne4onnx==2.0.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.0.1)
# Requirement already satisfied: sng4onnx==2.0.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (2.0.1)
# Requirement already satisfied: psutil==5.9.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (5.9.5)
# Requirement already satisfied: protobuf==4.25.5 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (4.25.5)
# Requirement already satisfied: h5py==3.12.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (3.12.1)
# Requirement already satisfied: ml-dtypes==0.5.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (0.5.1)
# Requirement already satisfied: flatbuffers==25.12.19 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (25.12.19)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (4.67.1)
# Requirement already satisfied: pytest==9.0.2 in /usr/local/lib/python3.12/dist-packages (from onnx2tf==2.3.16) (9.0.2)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2->onnx2tf==2.3.16) (1.2.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert==2.1.2->onnx2tf==2.3.16) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3->onnx2tf==2.3.16) (26.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.24.3->onnx2tf==2.3.16) (1.13.1)
# Requirement already satisfied: onnx_ir<2,>=0.1.15 in /usr/local/lib/python3.12/dist-packages (from onnxscript==0.6.2->onnx2tf==2.3.16) (0.2.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim-prebuilt==0.4.39.post2->onnx2tf==2.3.16) (13.9.4)
# Requirement already satisfied: iniconfig>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf==2.3.16) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf==2.3.16) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest==9.0.2->onnx2tf==2.3.16) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->onnx2tf==2.3.16) (2026.2.25)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (1.78.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0->onnx2tf==2.3.16) (3.13.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.46.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.19.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime==1.24.3->onnx2tf==2.3.16) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (3.1.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim-prebuilt==0.4.39.post2->onnx2tf==2.3.16) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim-prebuilt==0.4.39.post2->onnx2tf==2.3.16) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.0->onnx2tf==2.3.16) (3.0.3)
# Using cached onnx2tf-2.3.16-py3-none-any.whl (1.9 MB)
# Using cached onnxscript-0.6.2-py3-none-any.whl (689 kB)
# Using cached onnx_graphsurgeon-0.5.8-py2.py3-none-any.whl (57 kB)
# Installing collected packages: onnx_graphsurgeon, onnxscript, onnx2tf
#   Attempting uninstall: onnxscript
#     Found existing installation: onnxscript 0.5.4
#     Uninstalling onnxscript-0.5.4:
#       Successfully uninstalled onnxscript-0.5.4
# Successfully installed onnx2tf-2.3.16 onnx_graphsurgeon-0.5.8 onnxscript-0.6.2

# %%
# !onnx2tf -i /content/my_custom_model/dayn_jer_di_tected.onnx -o /content/my_custom_model/ -kat onnx____Flatten_0
# !mv /content/my_custom_model/dayn_jer_di_tected_float32.tflite /content/my_custom_model/dayn_jer_di_tected.tflite
# Out:
# Model optimizing started ============================================================
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 4              │ 4                │
# │ Constant   │ 14             │ 12               │
# │ Div        │ 2              │ 2                │
# │ Flatten    │ 1              │ 1                │
# │ Gemm       │ 3              │ 3                │
# │ Mul        │ 2              │ 2                │
# │ Pow        │ 2              │ 2                │
# │ ReduceMean │ 4              │ 4                │
# │ Relu       │ 2              │ 2                │
# │ Sigmoid    │ 1              │ 1                │
# │ Sqrt       │ 2              │ 2                │
# │ Sub        │ 2              │ 2                │
# │ Model Size │ 200.6KiB       │ 201.4KiB         │
# └────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 4              │ 4                │
# │ Constant   │ 12             │ 12               │
# │ Div        │ 2              │ 2                │
# │ Flatten    │ 1              │ 1                │
# │ Gemm       │ 3              │ 3                │
# │ Mul        │ 2              │ 2                │
# │ Pow        │ 2              │ 2                │
# │ ReduceMean │ 4              │ 4                │
# │ Relu       │ 2              │ 2                │
# │ Sigmoid    │ 1              │ 1                │
# │ Sqrt       │ 2              │ 2                │
# │ Sub        │ 2              │ 2                │
# │ Model Size │ 201.4KiB       │ 201.4KiB         │
# └────────────┴────────────────┴──────────────────┘
#
# Simplifying...
# Finish! Here is the difference:
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃            ┃ Original Model ┃ Simplified Model ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │ Add        │ 4              │ 4                │
# │ Constant   │ 12             │ 12               │
# │ Div        │ 2              │ 2                │
# │ Flatten    │ 1              │ 1                │
# │ Gemm       │ 3              │ 3                │
# │ Mul        │ 2              │ 2                │
# │ Pow        │ 2              │ 2                │
# │ ReduceMean │ 4              │ 4                │
# │ Relu       │ 2              │ 2                │
# │ Sigmoid    │ 1              │ 1                │
# │ Sqrt       │ 2              │ 2                │
# │ Sub        │ 2              │ 2                │
# │ Model Size │ 201.4KiB       │ 201.4KiB         │
# └────────────┴────────────────┴──────────────────┘
#
# Model optimizing complete!
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: onnx____Flatten_0 shape: [1, 16, 96] dtype: float32
# onnxruntime output memmap enabled. Outputs: 25, Path: /tmp/onnx2tf_ort_mm_ufih_ner
#
# INFO: 2 / 26
# INFO: onnx_op_type: Flatten onnx_op_name: /flatten/Flatten
# INFO:  input_name.1: onnx____Flatten_0 shape: [1, 16, 96] dtype: float32
# INFO:  output_name.1: /flatten/Flatten_output_0 shape: [1, 1536] dtype: float32
# INFO: tf_op_type: reshape
# INFO:  input.1.tensor: name: onnx____Flatten_0 shape: (1, 16, 96) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [1, 1536]
# INFO:  output.1.output: name: tf.reshape/Reshape:0 shape: (1, 1536) dtype: <dtype: 'float32'>
#
# INFO: 3 / 26
# INFO: onnx_op_type: Gemm onnx_op_name: /layer1/Gemm
# INFO:  input_name.1: /flatten/Flatten_output_0 shape: [1, 1536] dtype: float32
# INFO:  input_name.2: layer1.weight shape: [32, 1536] dtype: float32
# INFO:  input_name.3: layer1.bias shape: [32] dtype: float32
# INFO:  output_name.1: /layer1/Gemm_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.x: name: Placeholder:0 shape: (1, 1536) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1536, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.z: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.alpha: val: 1.0
# INFO:  input.5.beta: val: 1.0
# INFO:  output.1.output: name: tf.__operators__.add/AddV2:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 4 / 26
# INFO: onnx_op_type: ReduceMean onnx_op_name: /layernorm1/ReduceMean
# INFO:  input_name.1: /layer1/Gemm_output_0 shape: [1, 32] dtype: float32
# INFO:  output_name.1: /layernorm1/ReduceMean_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 1
# INFO:  input.2.input_tensor: name: tf.__operators__.add/AddV2:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_1/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 5 / 26
# INFO: onnx_op_type: Sub onnx_op_name: /layernorm1/Sub
# INFO:  input_name.1: /layer1/Gemm_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: /layernorm1/ReduceMean_output_0 shape: [1, 1] dtype: float32
# INFO:  output_name.1: /layernorm1/Sub_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.__operators__.add/AddV2:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.reduce_mean_1/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract/Sub:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 6 / 26
# INFO: onnx_op_type: Pow onnx_op_name: /layernorm1/Pow
# INFO:  input_name.1: /layernorm1/Sub_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: /layernorm1/Constant_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /layernorm1/Pow_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.subtract/Sub:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_4/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 7 / 26
# INFO: onnx_op_type: ReduceMean onnx_op_name: /layernorm1/ReduceMean_1
# INFO:  input_name.1: /layernorm1/Pow_output_0 shape: [1, 32] dtype: float32
# INFO:  output_name.1: /layernorm1/ReduceMean_1_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 1
# INFO:  input.2.input_tensor: name: tf.math.multiply_4/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_3/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 8 / 26
# INFO: onnx_op_type: Add onnx_op_name: /layernorm1/Add
# INFO:  input_name.1: /layernorm1/ReduceMean_1_output_0 shape: [1, 1] dtype: float32
# INFO:  input_name.2: /layernorm1/Constant_1_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /layernorm1/Add_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.reduce_mean_3/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 9 / 26
# INFO: onnx_op_type: Sqrt onnx_op_name: /layernorm1/Sqrt
# INFO:  input_name.1: /layernorm1/Add_output_0 shape: [1, 1] dtype: float32
# INFO:  output_name.1: /layernorm1/Sqrt_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: sqrt
# INFO:  input.1.x: name: tf.math.add/Add:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sqrt/Sqrt:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 10 / 26
# INFO: onnx_op_type: Div onnx_op_name: /layernorm1/Div
# INFO:  input_name.1: /layernorm1/Sub_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: /layernorm1/Sqrt_output_0 shape: [1, 1] dtype: float32
# INFO:  output_name.1: /layernorm1/Div_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.math.subtract/Sub:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sqrt/Sqrt:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide/truediv:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 11 / 26
# INFO: onnx_op_type: Mul onnx_op_name: /layernorm1/Mul
# INFO:  input_name.1: /layernorm1/Div_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: layernorm1.weight shape: [32] dtype: float32
# INFO:  output_name.1: /layernorm1/Mul_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.divide/truediv:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 32) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_10/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 12 / 26
# INFO: onnx_op_type: Add onnx_op_name: /layernorm1/Add_1
# INFO:  input_name.1: /layernorm1/Mul_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: layernorm1.bias shape: [32] dtype: float32
# INFO:  output_name.1: /layernorm1/Add_1_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.multiply_10/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 32) dtype: float32
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 13 / 26
# INFO: onnx_op_type: Relu onnx_op_name: /relu1/Relu
# INFO:  input_name.1: /layernorm1/Add_1_output_0 shape: [1, 32] dtype: float32
# INFO:  output_name.1: /relu1/Relu_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_1/Add:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu/Relu:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 14 / 26
# INFO: onnx_op_type: Gemm onnx_op_name: /blocks.0/fcn_layer/Gemm
# INFO:  input_name.1: /relu1/Relu_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: blocks.0.fcn_layer.weight shape: [32, 32] dtype: float32
# INFO:  input_name.3: blocks.0.fcn_layer.bias shape: [32] dtype: float32
# INFO:  output_name.1: /blocks.0/fcn_layer/Gemm_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.x: name: Placeholder:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.z: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.alpha: val: 1.0
# INFO:  input.5.beta: val: 1.0
# INFO:  output.1.output: name: tf.__operators__.add_1/AddV2:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 15 / 26
# INFO: onnx_op_type: ReduceMean onnx_op_name: /blocks.0/layer_norm/ReduceMean
# INFO:  input_name.1: /blocks.0/fcn_layer/Gemm_output_0 shape: [1, 32] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/ReduceMean_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 1
# INFO:  input.2.input_tensor: name: tf.__operators__.add_1/AddV2:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_5/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 16 / 26
# INFO: onnx_op_type: Sub onnx_op_name: /blocks.0/layer_norm/Sub
# INFO:  input_name.1: /blocks.0/fcn_layer/Gemm_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: /blocks.0/layer_norm/ReduceMean_output_0 shape: [1, 1] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/Sub_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: subtract
# INFO:  input.1.x: name: tf.__operators__.add_1/AddV2:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.reduce_mean_5/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.subtract_1/Sub:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 17 / 26
# INFO: onnx_op_type: Pow onnx_op_name: /blocks.0/layer_norm/Pow
# INFO:  input_name.1: /blocks.0/layer_norm/Sub_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: /layernorm1/Constant_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/Pow_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: pow
# INFO:  input.1.x: name: tf.math.subtract_1/Sub:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: () dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_16/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 18 / 26
# INFO: onnx_op_type: ReduceMean onnx_op_name: /blocks.0/layer_norm/ReduceMean_1
# INFO:  input_name.1: /blocks.0/layer_norm/Pow_output_0 shape: [1, 32] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/ReduceMean_1_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: reduce_mean
# INFO:  input.1.axis0: val: 1
# INFO:  input.2.input_tensor: name: tf.math.multiply_16/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.keepdims: val: True
# INFO:  output.1.output: name: tf.math.reduce_mean_7/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 19 / 26
# INFO: onnx_op_type: Add onnx_op_name: /blocks.0/layer_norm/Add
# INFO:  input_name.1: /blocks.0/layer_norm/ReduceMean_1_output_0 shape: [1, 1] dtype: float32
# INFO:  input_name.2: /layernorm1/Constant_1_output_0 shape: [] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/Add_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.reduce_mean_7/Mean:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 20 / 26
# INFO: onnx_op_type: Sqrt onnx_op_name: /blocks.0/layer_norm/Sqrt
# INFO:  input_name.1: /blocks.0/layer_norm/Add_output_0 shape: [1, 1] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/Sqrt_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: sqrt
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sqrt_1/Sqrt:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 21 / 26
# INFO: onnx_op_type: Div onnx_op_name: /blocks.0/layer_norm/Div
# INFO:  input_name.1: /blocks.0/layer_norm/Sub_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: /blocks.0/layer_norm/Sqrt_output_0 shape: [1, 1] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/Div_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: divide
# INFO:  input.1.x: name: tf.math.subtract_1/Sub:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sqrt_1/Sqrt:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.divide_1/truediv:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 22 / 26
# INFO: onnx_op_type: Mul onnx_op_name: /blocks.0/layer_norm/Mul
# INFO:  input_name.1: /blocks.0/layer_norm/Div_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: blocks.0.layer_norm.weight shape: [32] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/Mul_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.divide_1/truediv:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 32) dtype: float32
# INFO:  output.1.output: name: tf.math.multiply_22/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 23 / 26
# INFO: onnx_op_type: Add onnx_op_name: /blocks.0/layer_norm/Add_1
# INFO:  input_name.1: /blocks.0/layer_norm/Mul_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: blocks.0.layer_norm.bias shape: [32] dtype: float32
# INFO:  output_name.1: /blocks.0/layer_norm/Add_1_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.multiply_22/Mul:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 32) dtype: float32
# INFO:  output.1.output: name: tf.math.add_3/Add:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 24 / 26
# INFO: onnx_op_type: Relu onnx_op_name: /blocks.0/relu/Relu
# INFO:  input_name.1: /blocks.0/layer_norm/Add_1_output_0 shape: [1, 32] dtype: float32
# INFO:  output_name.1: /blocks.0/relu/Relu_output_0 shape: [1, 32] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_3/Add:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_1/Relu:0 shape: (1, 32) dtype: <dtype: 'float32'>
#
# INFO: 25 / 26
# INFO: onnx_op_type: Gemm onnx_op_name: /last_layer/Gemm
# INFO:  input_name.1: /blocks.0/relu/Relu_output_0 shape: [1, 32] dtype: float32
# INFO:  input_name.2: last_layer.weight shape: [1, 32] dtype: float32
# INFO:  input_name.3: last_layer.bias shape: [1] dtype: float32
# INFO:  output_name.1: /last_layer/Gemm_output_0 shape: [1, 1] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.x: name: Placeholder:0 shape: (1, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (32, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.z: shape: (1,) dtype: <dtype: 'float32'>
# INFO:  input.4.alpha: val: 1.0
# INFO:  input.5.beta: val: 1.0
# INFO:  output.1.output: name: tf.__operators__.add_2/AddV2:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# INFO: 26 / 26
# INFO: onnx_op_type: Sigmoid onnx_op_name: /last_act/Sigmoid
# INFO:  input_name.1: /last_layer/Gemm_output_0 shape: [1, 1] dtype: float32
# INFO:  output_name.1: 39 shape: [1, 1] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.__operators__.add_2/AddV2:0 shape: (1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid/Sigmoid:0 shape: (1, 1) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# Saved artifact at '/content/my_custom_model/'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 16, 96), dtype=tf.float32, name='onnx____Flatten_0')
# Output Type:
#   TensorSpec(shape=(1, 1), dtype=tf.float32, name=None)
# saved_model output complete!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1774913765.549594   60574 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1774913765.549665   60574 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1774913765.557640   60574 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Float32 tflite output complete!
# W0000 00:00:1774913767.024146   60574 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1774913767.024201   60574 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Float16 tflite output complete!

# %%
from google.colab import files
files.download("/content/my_custom_model/dayn_jer_di_tected.onnx")
files.download("/content/my_custom_model/dayn_jer_di_tected.tflite")

# %%
# !pip install openwakeword

from openwakeword.model import Model

model = Model(
    wakeword_models=["/content/my_custom_model/variables/dayn_jer_di_tected.onnx"]
    # Could also use the .tflite file here
)

# Test on a 16 kHz, 16-bit PCM wav file
preds = model.predict_clip("/content/test_audio.wav")

print(preds)
# Out:
# Requirement already satisfied: openwakeword in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: onnxruntime<2,>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from openwakeword) (1.24.3)
# Requirement already satisfied: ai-edge-litert<3,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from openwakeword) (2.1.2)
# Requirement already satisfied: speexdsp-ns<1,>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from openwakeword) (0.1.2)
# Requirement already satisfied: tqdm<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from openwakeword) (4.67.1)
# Requirement already satisfied: scipy<2,>=1.3 in /usr/local/lib/python3.12/dist-packages (from openwakeword) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.12/dist-packages (from openwakeword) (1.6.1)
# Requirement already satisfied: requests<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from openwakeword) (2.32.5)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert<3,>=2.0.2->openwakeword) (1.2.8)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert<3,>=2.0.2->openwakeword) (25.12.19)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert<3,>=2.0.2->openwakeword) (1.26.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert<3,>=2.0.2->openwakeword) (4.15.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert<3,>=2.0.2->openwakeword) (4.25.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.10.0->openwakeword) (26.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.10.0->openwakeword) (1.13.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openwakeword) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openwakeword) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openwakeword) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0->openwakeword) (2026.2.25)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2,>=1->openwakeword) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2,>=1->openwakeword) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.10.0->openwakeword) (1.3.0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_38433/1908868697.py in <cell line: 0>()
#       3 from openwakeword.model import Model
#       4
# ----> 5 model = Model(
#       6     wakeword_models=["/content/my_custom_model/variables/dayn_jer_di_tected.onnx"]
#       7     # or use the .onnx file instead
#
# /content/openwakeword/openwakeword/utils.py in wrapped(*args, **kwargs)
#     684                                     f"will be removed in future releases. Use '{kwarg_map[k]}' instead.")
#     685                 new_kwargs[kwarg_map.get(k, k)] = v
# --> 686             return func(*args, **new_kwargs)
#     687         return wrapped
#     688     return decorator
#
# /content/openwakeword/openwakeword/model.py in __init__(self, wakeword_models, class_mapping_dicts, enable_speex_noise_suppression, vad_threshold, custom_verifier_models, custom_verifier_threshold, inference_framework, **kwargs)
#      82         """
#      83         # Get model paths for pre-trained models if user doesn't provide models to load
# ---> 84         pretrained_model_paths = openwakeword.get_pretrained_model_paths(inference_framework)
#      85         wakeword_model_names = []
#      86         if wakeword_models == []:
#
# AttributeError: module 'openwakeword' has no attribute 'get_pretrained_model_paths'

# %%
import os
import sys
import importlib

sys.path.insert(0, "/content/openwakeword")

import openwakeword
importlib.reload(openwakeword)

print("openwakeword module path:", openwakeword.__file__)

from openwakeword.model import Model

model_path = "/content/my_custom_model/dayn_jer_di_tected.tflite"
print("model exists:", os.path.exists(model_path))

model = Model(
    wakeword_models=[model_path],
    inference_framework="tflite"
)
# Out:
# openwakeword module path: /content/openwakeword/openwakeword/__init__.py
# model exists: True

# %%
#Upload the wav files to the runtime folder to test it
#The tests worked correctly

import os
print(os.path.exists("/content/DangerDetected.wav"))

preds = model.predict_clip("/content/DangerDetected.wav")
print(preds)

threshold = 0.5
detected = any(x["dayn_jer_di_tected"] >= threshold for x in preds)
print("Detected:", detected)
# Out:
# True
# [{'dayn_jer_di_tected': 0.00075492205}, {'dayn_jer_di_tected': 0.00078374863}, {'dayn_jer_di_tected': 0.00074432575}, {'dayn_jer_di_tected': 0.0007366514}, {'dayn_jer_di_tected': 0.00074588007}, {'dayn_jer_di_tected': 0.0007599784}, {'dayn_jer_di_tected': 0.00076352875}, {'dayn_jer_di_tected': 0.0007638737}, {'dayn_jer_di_tected': 0.0007675677}, {'dayn_jer_di_tected': 0.000769964}, {'dayn_jer_di_tected': 0.000777967}, {'dayn_jer_di_tected': 0.000783373}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.000781905}, {'dayn_jer_di_tected': 0.00077610335}, {'dayn_jer_di_tected': 0.0007687137}, {'dayn_jer_di_tected': 0.00077267294}, {'dayn_jer_di_tected': 0.00077445497}, {'dayn_jer_di_tected': 0.00078242144}, {'dayn_jer_di_tected': 0.00077240943}, {'dayn_jer_di_tected': 0.00077118597}, {'dayn_jer_di_tected': 0.0007611036}, {'dayn_jer_di_tected': 0.00080414757}, {'dayn_jer_di_tected': 0.00076777616}, {'dayn_jer_di_tected': 0.0007913512}, {'dayn_jer_di_tected': 0.00079203106}, {'dayn_jer_di_tected': 0.0008254352}, {'dayn_jer_di_tected': 0.00083105563}, {'dayn_jer_di_tected': 0.000822516}, {'dayn_jer_di_tected': 0.0007672606}, {'dayn_jer_di_tected': 0.0007683337}, {'dayn_jer_di_tected': 0.0008628059}, {'dayn_jer_di_tected': 0.00405784}, {'dayn_jer_di_tected': 0.9081172}, {'dayn_jer_di_tected': 0.92644584}, {'dayn_jer_di_tected': 0.93036985}, {'dayn_jer_di_tected': 0.9313849}, {'dayn_jer_di_tected': 0.92332065}, {'dayn_jer_di_tected': 0.9077946}, {'dayn_jer_di_tected': 0.0530684}, {'dayn_jer_di_tected': 0.0009083928}, {'dayn_jer_di_tected': 0.000772776}, {'dayn_jer_di_tected': 0.0007694561}, {'dayn_jer_di_tected': 0.00077378156}, {'dayn_jer_di_tected': 0.0007607514}, {'dayn_jer_di_tected': 0.00074491196}, {'dayn_jer_di_tected': 0.0007408236}, {'dayn_jer_di_tected': 0.00075941515}, {'dayn_jer_di_tected': 0.00076060946}, {'dayn_jer_di_tected': 0.00075723376}, {'dayn_jer_di_tected': 0.00075835676}, {'dayn_jer_di_tected': 0.0007536369}, {'dayn_jer_di_tected': 0.0007464098}, {'dayn_jer_di_tected': 0.0007373555}, {'dayn_jer_di_tected': 0.000740854}]
# Detected: True

# %%
import os
print(os.path.exists("/content/NoDanger.wav"))

preds = model.predict_clip("/content/NoDanger.wav")
print(preds)

threshold = 0.5
detected = any(x["dayn_jer_di_tected"] >= threshold for x in preds)
print("Detected:", detected)
# Out:
# True
# [{'dayn_jer_di_tected': 0.00075492205}, {'dayn_jer_di_tected': 0.00078374863}, {'dayn_jer_di_tected': 0.00074432575}, {'dayn_jer_di_tected': 0.0007366514}, {'dayn_jer_di_tected': 0.00074588007}, {'dayn_jer_di_tected': 0.0007599784}, {'dayn_jer_di_tected': 0.00076352875}, {'dayn_jer_di_tected': 0.0007638737}, {'dayn_jer_di_tected': 0.0007675677}, {'dayn_jer_di_tected': 0.000769964}, {'dayn_jer_di_tected': 0.000777967}, {'dayn_jer_di_tected': 0.000783373}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078161963}, {'dayn_jer_di_tected': 0.00077781355}, {'dayn_jer_di_tected': 0.000777055}, {'dayn_jer_di_tected': 0.00078368373}, {'dayn_jer_di_tected': 0.0007870376}, {'dayn_jer_di_tected': 0.00077834266}, {'dayn_jer_di_tected': 0.0007521431}, {'dayn_jer_di_tected': 0.00075397413}, {'dayn_jer_di_tected': 0.0007532933}, {'dayn_jer_di_tected': 0.0008274189}, {'dayn_jer_di_tected': 0.00086012005}, {'dayn_jer_di_tected': 0.00089857995}, {'dayn_jer_di_tected': 0.0009158607}, {'dayn_jer_di_tected': 0.000973663}, {'dayn_jer_di_tected': 0.0010962156}, {'dayn_jer_di_tected': 0.0007819363}, {'dayn_jer_di_tected': 0.00080842903}, {'dayn_jer_di_tected': 0.0008835728}, {'dayn_jer_di_tected': 0.0008812748}, {'dayn_jer_di_tected': 0.0009044687}, {'dayn_jer_di_tected': 0.00076251663}, {'dayn_jer_di_tected': 0.00077808823}, {'dayn_jer_di_tected': 0.0007449417}, {'dayn_jer_di_tected': 0.00076646806}, {'dayn_jer_di_tected': 0.00078362017}, {'dayn_jer_di_tected': 0.0007651035}, {'dayn_jer_di_tected': 0.00075948203}, {'dayn_jer_di_tected': 0.0007464383}, {'dayn_jer_di_tected': 0.0007434053}, {'dayn_jer_di_tected': 0.00074673246}, {'dayn_jer_di_tected': 0.0007468641}, {'dayn_jer_di_tected': 0.0007517619}]
# Detected: False

# %%
import os
print(os.path.exists("/content/DoorwayClosed.wav"))

preds = model.predict_clip("/content/DoorwayClosed.wav")
print(preds)

threshold = 0.5
detected = any(x["dayn_jer_di_tected"] >= threshold for x in preds)
print("Detected:", detected)
# Out:
# True
# [{'dayn_jer_di_tected': 0.0007598433}, {'dayn_jer_di_tected': 0.00076082617}, {'dayn_jer_di_tected': 0.0007528204}, {'dayn_jer_di_tected': 0.0007481884}, {'dayn_jer_di_tected': 0.00075060513}, {'dayn_jer_di_tected': 0.0007669667}, {'dayn_jer_di_tected': 0.00077381544}, {'dayn_jer_di_tected': 0.00077031227}, {'dayn_jer_di_tected': 0.0007695313}, {'dayn_jer_di_tected': 0.00077160564}, {'dayn_jer_di_tected': 0.00077547453}, {'dayn_jer_di_tected': 0.0007815973}, {'dayn_jer_di_tected': 0.000784737}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078601186}, {'dayn_jer_di_tected': 0.00078189827}, {'dayn_jer_di_tected': 0.00077260076}, {'dayn_jer_di_tected': 0.000774251}, {'dayn_jer_di_tected': 0.00076320325}, {'dayn_jer_di_tected': 0.0007525174}, {'dayn_jer_di_tected': 0.0007460287}, {'dayn_jer_di_tected': 0.0007366318}, {'dayn_jer_di_tected': 0.00074269896}, {'dayn_jer_di_tected': 0.00073639385}, {'dayn_jer_di_tected': 0.00074626686}, {'dayn_jer_di_tected': 0.00075616513}, {'dayn_jer_di_tected': 0.00078543124}, {'dayn_jer_di_tected': 0.00076208217}, {'dayn_jer_di_tected': 0.0007636412}, {'dayn_jer_di_tected': 0.00077972637}, {'dayn_jer_di_tected': 0.0007697855}, {'dayn_jer_di_tected': 0.0007850537}, {'dayn_jer_di_tected': 0.0007831242}, {'dayn_jer_di_tected': 0.00080156524}, {'dayn_jer_di_tected': 0.0007705076}, {'dayn_jer_di_tected': 0.0007904947}, {'dayn_jer_di_tected': 0.00080799544}, {'dayn_jer_di_tected': 0.0007969304}, {'dayn_jer_di_tected': 0.00080560986}, {'dayn_jer_di_tected': 0.00079639896}, {'dayn_jer_di_tected': 0.0007789974}, {'dayn_jer_di_tected': 0.000742853}, {'dayn_jer_di_tected': 0.00075080787}, {'dayn_jer_di_tected': 0.0007539799}, {'dayn_jer_di_tected': 0.00075840804}, {'dayn_jer_di_tected': 0.000746003}, {'dayn_jer_di_tected': 0.00074946287}, {'dayn_jer_di_tected': 0.00078372995}, {'dayn_jer_di_tected': 0.0007772394}, {'dayn_jer_di_tected': 0.0007594289}, {'dayn_jer_di_tected': 0.00074237987}, {'dayn_jer_di_tected': 0.00075325486}, {'dayn_jer_di_tected': 0.0007594437}, {'dayn_jer_di_tected': 0.00074239227}, {'dayn_jer_di_tected': 0.000740348}, {'dayn_jer_di_tected': 0.00073652406}, {'dayn_jer_di_tected': 0.0007488129}]
# Detected: False
